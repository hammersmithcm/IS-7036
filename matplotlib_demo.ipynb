# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 40]


plt.plot(x, y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Line Plot')
plt.show()

# %%
plt.scatter(x, y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot')
plt.show()

# %%
#changing parts of graph: like color and fontsize
plt.scatter(x, y, c ="green", edgecolor ="black")
plt.xlabel('X-axis', fontsize =14)
plt.ylabel('Y-axis', fontsize =14)
plt.title('Scatter Plot', fontsize = 18, weight='bold')
plt.show()

# %%
titanic =pd.read_csv("titanic_clean.csv")
titanic.head(10)
# Out:
#    Unnamed: 0  pclass  survived  \
# 0           1     1.0       1.0
# 1           2     1.0       1.0
# 2           3     1.0       0.0
# 3           4     1.0       0.0
# 4           5     1.0       0.0
# 5           6     1.0       1.0
# 6           7     1.0       1.0
# 7           8     1.0       0.0
# 8           9     1.0       1.0
# 9          10     1.0       0.0
#
#                                               name     sex      age  sibsp  \
# 0                    Allen, Miss. Elisabeth Walton  female  29.0000    0.0
# 1                   Allison, Master. Hudson Trevor    male   0.9167    1.0
# 2                     Allison, Miss. Helen Loraine  female   2.0000    1.0
# 3             Allison, Mr. Hudson Joshua Creighton    male  30.0000    1.0
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000    1.0
# 5                              Anderson, Mr. Harry    male  48.0000    0.0
# 6                Andrews, Miss. Kornelia Theodosia  female  63.0000    1.0
# ...

# %%
titanic['age'].dtype
# Out:
# dtype('float64')

# %%
age_data = titanic['age'].dropna()

# %%
#to determine bin width
max_val = np.max(age_data)
max_val
# Out:
# 80.0

# %%
plt.figure(figsize=(8, 6))
plt.hist(age_data, bins=8, color="darksalmon", edgecolor="white", alpha=0.7)
plt.title("Age Distribution of Titanic passengers", fontsize=17, weight="bold")
plt.xlabel("Age", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()
